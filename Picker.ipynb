# %% [markdown]
# # Simple waveform viewer
#
# This applet will download some waveform data for a known event, then plot those data in an interactive plotting
# window.
# - You can zoom in on these data using the box-zoom tool ![box-zoom icon](https://docs.bokeh.org/en/1.1.0/_images/BoxZoom.png)
# - Undo and redo your movements
# - Pan around using the panning tool ![panning icon](https://docs.bokeh.org/en/1.1.0/_images/Pan.png)
# - and save the image to a png if you want.
#
# When you move your mouse over the images a hover window should appear telling you the time and amplitude of the data at that point.
#
# To run the applet and start interactive plotting you should select the cell below and press the run button (or ctrl-enter on your keyboard).

# %%
from bokeh.io import output_notebook
output_notebook()
from helpers.bokeh_picker import Picker

Picker().pick()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>
# ...
#   <div class="bk-root" id="68e9d825-eb5e-4982-ab40-47641c1f8d87" data-root-id="1908"></div>
